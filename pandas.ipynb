# %%
import pandas as pd
df = pd.read_csv("ted_main.csv", encoding = "utf-8")
df
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1          265  With the same humor and humanity he exuded in ...       977
# 2          124  New York Times columnist David Pogue takes aim...      1286
# 3          200  In an emotionally charged talk, MacArthur-winn...      1116
# 4          593  You've never seen data presented like this. Wi...      1190
# ...        ...                                                ...       ...
# 2545        17  Between 2008 and 2016, the United States depor...       476
# 2546         6  How can you study Mars without a spaceship? He...       290
# 2547        10  Science fiction visions of the future show us ...       651
# 2548        32  In an unmissable talk about race and politics ...      1100
# 2549         8  With more than half of the world population li...       519
#
# ...

# %%
df.shape
# Out:
# (2550, 17)

# %%
df[['comments', 'description', 'url']]
# Out:
#       comments                                        description  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...
# 1          265  With the same humor and humanity he exuded in ...
# 2          124  New York Times columnist David Pogue takes aim...
# 3          200  In an emotionally charged talk, MacArthur-winn...
# 4          593  You've never seen data presented like this. Wi...
# ...        ...                                                ...
# 2545        17  Between 2008 and 2016, the United States depor...
# 2546         6  How can you study Mars without a spaceship? He...
# 2547        10  Science fiction visions of the future show us ...
# 2548        32  In an unmissable talk about race and politics ...
# 2549         8  With more than half of the world population li...
#
#                                                     url
# 0     https://www.ted.com/talks/ken_robinson_says_sc...
# 1     https://www.ted.com/talks/al_gore_on_averting_...
# ...

# %%
df.iloc[0]
# Out:
# comments                                                           4553
# description           Sir Ken Robinson makes an entertaining and pro...
# duration                                                           1164
# event                                                           TED2006
# film_date                                                    1140825600
# languages                                                            60
# main_speaker                                               Ken Robinson
# name                          Ken Robinson: Do schools kill creativity?
# num_speaker                                                           1
# published_date                                               1151367060
# ratings               [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# related_talks         [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...
# speaker_occupation                                      Author/educator
# ...

# %%
df.iloc[10:15]
# Out:
#     comments                                        description  duration  \
# 10        79  Accepting his 2006 TED Prize, Cameron Sinclair...      1414
# 11        55  Jehane Noujaim unveils her 2006 TED Prize wish...      1538
# 12        71  Accepting the 2006 TED Prize, Dr. Larry Brilli...      1550
# 13       242  Jeff Han shows off a cheap, scalable multi-tou...       527
# 14        99  Nicholas Negroponte, founder of the MIT Media ...      1057
#
#       event   film_date  languages         main_speaker  \
# 10  TED2006  1140912000         27     Cameron Sinclair
# 11  TED2006  1140912000         20       Jehane Noujaim
# 12  TED2006  1140652800         24      Larry Brilliant
# 13  TED2006  1139184000         27             Jeff Han
# 14  TED2006  1140652800         25  Nicholas Negroponte
#
#                                                  name  num_speaker  \
# 10  Cameron Sinclair: My wish: A call for open-sou...            1
# ...

# %%
df.head(5)
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  1140825600         60   Ken Robinson
# 1  TED2006  1140825600         43        Al Gore
# 2  TED2006  1140739200         26    David Pogue
# 3  TED2006  1140912000         35  Majora Carter
# 4  TED2006  1140566400         48   Hans Rosling
#
#                                             name  num_speaker  published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1      1151367060
# ...

# %%
df.tail(5)
# Out:
#       comments                                        description  duration  \
# 2545        17  Between 2008 and 2016, the United States depor...       476
# 2546         6  How can you study Mars without a spaceship? He...       290
# 2547        10  Science fiction visions of the future show us ...       651
# 2548        32  In an unmissable talk about race and politics ...      1100
# 2549         8  With more than half of the world population li...       519
#
#              event   film_date  languages         main_speaker  \
# 2545       TED2017  1496707200          4     Duarte Geraldino
# 2546       TED2017  1492992000          3  Armando Azua-Bustos
# 2547       TED2017  1492992000          1       Radhika Nagpal
# 2548  TEDxMileHigh  1499472000          1     Theo E.J. Wilson
# 2549       TED2017  1492992000          1    Karoliina Korppoo
#
#                                                    name  num_speaker  \
# ...

# %%
df[['comments', 'description', 'duration']].iloc[:5]
# Out:
#    comments                                        description  duration
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190

# %%
test = df.iloc[:3]
test
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
#
#      event   film_date  languages  main_speaker  \
# 0  TED2006  1140825600         60  Ken Robinson
# 1  TED2006  1140825600         43       Al Gore
# 2  TED2006  1140739200         26   David Pogue
#
#                                         name  num_speaker  published_date  \
# 0  Ken Robinson: Do schools kill creativity?            1      1151367060
# 1       Al Gore: Averting the climate crisis            1      1151367060
# 2              David Pogue: Simplicity sells            1      1151367060
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# ...

# %%
test[ [True, False, True]]
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 2       124  New York Times columnist David Pogue takes aim...      1286
#
#      event   film_date  languages  main_speaker  \
# 0  TED2006  1140825600         60  Ken Robinson
# 2  TED2006  1140739200         26   David Pogue
#
#                                         name  num_speaker  published_date  \
# 0  Ken Robinson: Do schools kill creativity?            1      1151367060
# 2              David Pogue: Simplicity sells            1      1151367060
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 2  [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
#
#                                        related_talks    speaker_occupation  \
# 0  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...       Author/educator
# ...

# %%
bool_filter = df['description'].str.contains('Sir')  #str 字串list #對每個元素做布林判斷
bool_filter
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2545    False
# 2546    False
# 2547    False
# 2548    False
# 2549    False
# Name: description, Length: 2550, dtype: bool

# %%
df[bool_filter]
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 15         325  Violinist Sirena Huang gives a technically bri...      1481
# 54         203  Speaking as both an astronomer and "a concerne...      1046
# 692       1234  In this poignant, funny follow-up to his fable...      1008
# 833        473  In this talk from RSA Animate, Sir Ken Robinso...       700
# 1386       329  When most well-intentioned aid workers hear of...      1029
# 1502       634  Sir Ken Robinson outlines 3 principles crucial...      1151
# 1802        59  Sir Tim Berners-Lee invented the World Wide We...       403
# 1978        64  The founder of Sirius XM satellite radio, Mart...      1264
# 2192        61  Trust: How do you earn it? Banks use credit sc...       491
# 2503        20  How smart can our machines make us? Tom Gruber...       586
#
# ...

# %%
df [ df['description'].str.contains(r'\bSir\b') ] #正規化表示文字
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 54         203  Speaking as both an astronomer and "a concerne...      1046
# 692       1234  In this poignant, funny follow-up to his fable...      1008
# 833        473  In this talk from RSA Animate, Sir Ken Robinso...       700
# 1502       634  Sir Ken Robinson outlines 3 principles crucial...      1151
# 1802        59  Sir Tim Berners-Lee invented the World Wide We...       403
#
#                     event   film_date  languages     main_speaker  \
# 0                 TED2006  1140825600         60     Ken Robinson
# 54         TEDGlobal 2005  1121299200         29      Martin Rees
# 692               TED2010  1265414400         57     Ken Robinson
# 833           RSA Animate  1287014400          0     Ken Robinson
# 1502  TED Talks Education  1366675200         43     Ken Robinson
# ...

# %%
filter_df = df[ df['description'].str.contains(r'\bSir\b') ]
filter_df
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 54         203  Speaking as both an astronomer and "a concerne...      1046
# 692       1234  In this poignant, funny follow-up to his fable...      1008
# 833        473  In this talk from RSA Animate, Sir Ken Robinso...       700
# 1502       634  Sir Ken Robinson outlines 3 principles crucial...      1151
# 1802        59  Sir Tim Berners-Lee invented the World Wide We...       403
#
#                     event   film_date  languages     main_speaker  \
# 0                 TED2006  1140825600         60     Ken Robinson
# 54         TEDGlobal 2005  1121299200         29      Martin Rees
# 692               TED2010  1265414400         57     Ken Robinson
# 833           RSA Animate  1287014400          0     Ken Robinson
# 1502  TED Talks Education  1366675200         43     Ken Robinson
# ...

# %%
filter_df.to_csv('filter.csv', encoding = 'utf-8', index = False)

# %%
pd.read_csv('filter.csv', encoding = 'utf-8')
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       203  Speaking as both an astronomer and "a concerne...      1046
# 2      1234  In this poignant, funny follow-up to his fable...      1008
# 3       473  In this talk from RSA Animate, Sir Ken Robinso...       700
# 4       634  Sir Ken Robinson outlines 3 principles crucial...      1151
# 5        59  Sir Tim Berners-Lee invented the World Wide We...       403
#
#                  event   film_date  languages     main_speaker  \
# 0              TED2006  1140825600         60     Ken Robinson
# 1       TEDGlobal 2005  1121299200         29      Martin Rees
# 2              TED2010  1265414400         57     Ken Robinson
# 3          RSA Animate  1287014400          0     Ken Robinson
# 4  TED Talks Education  1366675200         43     Ken Robinson
# 5              TED2014  1394582400         29  Tim Berners-Lee
#
# ...

# %%
df.drop(['url', 'views'], axis=1) #axis= 0 刪除列 ， axis= 1 刪除行
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1          265  With the same humor and humanity he exuded in ...       977
# 2          124  New York Times columnist David Pogue takes aim...      1286
# 3          200  In an emotionally charged talk, MacArthur-winn...      1116
# 4          593  You've never seen data presented like this. Wi...      1190
# ...        ...                                                ...       ...
# 2545        17  Between 2008 and 2016, the United States depor...       476
# 2546         6  How can you study Mars without a spaceship? He...       290
# 2547        10  Science fiction visions of the future show us ...       651
# 2548        32  In an unmissable talk about race and politics ...      1100
# 2549         8  With more than half of the world population li...       519
#
# ...

# %%
df ['film_date']
# Out:
# 0       1140825600
# 1       1140825600
# 2       1140739200
# 3       1140912000
# 4       1140566400
#            ...
# 2545    1496707200
# 2546    1492992000
# 2547    1492992000
# 2548    1499472000
# 2549    1492992000
# Name: film_date, Length: 2550, dtype: int64

# %%
from datetime import datetime   #轉換西元時間模組
import pytz
print('原始:', df['film_date'][0])

print('轉換（當地時間）:', datetime.fromtimestamp(df['film_date'][0]) )
print('轉換（標準時間）:', datetime.utcfromtimestamp(df['film_date'][0]) )
# Out:
# 原始: 1140825600
# 轉換（當地時間）: 2006-02-25 08:00:00
# 轉換（標準時間）: 2006-02-25 00:00:00

# %%
def timeflow(data):
    return str(datetime.utcfromtimestamp(data))
df['film_date'].apply(timeflow)
# Out:
# 0       2006-02-25 00:00:00
# 1       2006-02-25 00:00:00
# 2       2006-02-24 00:00:00
# 3       2006-02-26 00:00:00
# 4       2006-02-22 00:00:00
#                ...
# 2545    2017-06-06 00:00:00
# 2546    2017-04-24 00:00:00
# 2547    2017-04-24 00:00:00
# 2548    2017-07-08 00:00:00
# 2549    2017-04-24 00:00:00
# Name: film_date, Length: 2550, dtype: object

# %%
df['film_date(datetime)'] = df['film_date'].apply(timeflow)
df[ ['film_date', 'film_date(datetime)']]   #設定回原表格
# Out:
#        film_date  film_date(datetime)
# 0     1140825600  2006-02-25 00:00:00
# 1     1140825600  2006-02-25 00:00:00
# 2     1140739200  2006-02-24 00:00:00
# 3     1140912000  2006-02-26 00:00:00
# 4     1140566400  2006-02-22 00:00:00
# ...          ...                  ...
# 2545  1496707200  2017-06-06 00:00:00
# 2546  1492992000  2017-04-24 00:00:00
# 2547  1492992000  2017-04-24 00:00:00
# 2548  1499472000  2017-07-08 00:00:00
# 2549  1492992000  2017-04-24 00:00:00
#
# [2550 rows x 2 columns]

# %%
def tag_filter(element):
    tag_list = eval(element) #element 每一格的資料
    if 'children' in tag_list:
        return True
bool_filter = df['tags'].apply(tag_filter)
bool_filter
# Out:
# 0       True
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 2545    None
# 2546    None
# 2547    None
# 2548    None
# 2549    None
# Name: tags, Length: 2550, dtype: object

# %%
df[bool_filter] [['description', 'tags']]
# Out:
#                                             description  \
# 4     You've never seen data presented like this. Wi...
# 117   Researcher Hans Rosling uses his cool data too...
# 359   Reporter Jennifer 8. Lee talks about her hunt ...
# 448   Nandan Nilekani, the visionary co-founder of o...
# 484   TED Fellow Sophal Ear shares the compelling st...
# 502   Talking at the US State Department this summer...
# 512   Vishal Vaid and his band explore a traditional...
# 523   Many people think the lines on the map no long...
# 558   Hans Rosling was a young guest student in Indi...
# 567   Sunitha Krishnan has dedicated her life to res...
# 573   Ryan Lobo has traveled the world, taking photo...
# 577   Shaffi Mather explains why he left his first c...
# 597   Collector Ravin Agrawal delivers a glowing int...
# 854   Speaking at a TED Salon in London, Martin Jacq...
# 1011  Economist Yasheng Huang compares China to Indi...
# 1027  Yang Lan, a journalist and entrepreneur who's ...
# ...

# %%
def tag_filter(element, filter_tag):
    tag_list = eval(element)
    if filter_tag in tag_list:
        return True
    else:
        return False
bool_filter = df['tags'].apply(tag_filter, filter_tag = 'Asia')
bool_filter
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 2545    False
# 2546    False
# 2547    False
# 2548    False
# 2549    False
# Name: tags, Length: 2550, dtype: bool

# %%
df[bool_filter] [['description', 'tags']]
# Out:
#                                             description  \
# 4     You've never seen data presented like this. Wi...
# 117   Researcher Hans Rosling uses his cool data too...
# 359   Reporter Jennifer 8. Lee talks about her hunt ...
# 448   Nandan Nilekani, the visionary co-founder of o...
# 484   TED Fellow Sophal Ear shares the compelling st...
# 502   Talking at the US State Department this summer...
# 512   Vishal Vaid and his band explore a traditional...
# 523   Many people think the lines on the map no long...
# 558   Hans Rosling was a young guest student in Indi...
# 567   Sunitha Krishnan has dedicated her life to res...
# 573   Ryan Lobo has traveled the world, taking photo...
# 577   Shaffi Mather explains why he left his first c...
# 597   Collector Ravin Agrawal delivers a glowing int...
# 854   Speaking at a TED Salon in London, Martin Jacq...
# 1011  Economist Yasheng Huang compares China to Indi...
# 1027  Yang Lan, a journalist and entrepreneur who's ...
# ...
